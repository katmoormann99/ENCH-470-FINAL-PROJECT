# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Test Test Test

# %%
test_df = pd.read_csv('daily_aqi_by_county_2020.csv')

# %%
test_df
# Out:
#        State Name county Name  State Code  County Code      Date  AQI  \
# 0         Alabama     Baldwin           1            3    1/1/20   48
# 1         Alabama     Baldwin           1            3    1/4/20   13
# 2         Alabama     Baldwin           1            3    1/7/20   14
# 3         Alabama     Baldwin           1            3   1/10/20   39
# 4         Alabama     Baldwin           1            3   1/13/20   29
# ...           ...         ...         ...          ...       ...  ...
# 338190    Wyoming      Weston          56           45  12/27/20   32
# 338191    Wyoming      Weston          56           45  12/28/20   30
# 338192    Wyoming      Weston          56           45  12/29/20   33
# 338193    Wyoming      Weston          56           45  12/30/20   33
# 338194    Wyoming      Weston          56           45  12/31/20   34
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
test_df.head()
# Out:
#   State Name county Name  State Code  County Code     Date  AQI Category  \
# 0    Alabama     Baldwin           1            3   1/1/20   48     Good
# 1    Alabama     Baldwin           1            3   1/4/20   13     Good
# 2    Alabama     Baldwin           1            3   1/7/20   14     Good
# 3    Alabama     Baldwin           1            3  1/10/20   39     Good
# 4    Alabama     Baldwin           1            3  1/13/20   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1
